# %% [markdown]
# # **Tecnológico de Costa Rica**
#
# ![TEC](https://www.eslared.net/sites/default/files/2020-06/tec_logo.png)
#
# ***IC-4213 / Inteligencia artificial***
#
# Autores
#
#
# *   **Sebastian Matey Rodriguez**
# *   **Liz Iveth Salazar Salazar**
# *   **Roosevelt Alejandro Pérez González**

# %% [markdown]
# # Análisis del Problema

# %% [markdown]
# En este notebook vamos a generar un modelo que prediga el precio del Bitcoin. Para elegir el mejor algoritmo primero es necesario ver las variables que componen este dataset.

# %% [markdown]
# # Entendimiento de los datos

# %%
import pandas as pd
import constants as const

# Load the CSV file into a DataFrame
df = pd.read_csv(const.CSV_BITCOIN_PATH)

df
# Out:
#               Date     Open     High      Low    Close         Volume  \
# 0     Jul 31, 2017  2763.24  2889.62  2720.61  2875.34    860,575,000
# 1     Jul 30, 2017  2724.39  2758.53  2644.85  2757.18    705,943,000
# 2     Jul 29, 2017  2807.02  2808.76  2692.80  2726.45    803,746,000
# 3     Jul 28, 2017  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 4     Jul 27, 2017  2538.71  2693.32  2529.34  2671.78    789,104,000
# ...            ...      ...      ...      ...      ...            ...
# 1551  May 02, 2013   116.38   125.60    92.28   105.21              -
# 1552  May 01, 2013   139.00   139.89   107.72   116.99              -
# 1553  Apr 30, 2013   144.00   146.93   134.05   139.00              -
# 1554  Apr 29, 2013   134.44   147.49   134.00   144.54              -
# 1555  Apr 28, 2013   135.30   135.98   132.10   134.21              -
#
#           Market Cap
# 0     45,535,800,000
# 1     44,890,700,000
# 2     46,246,700,000
# 3     44,144,400,000
# 4     41,816,500,000
# ...              ...
# 1551   1,292,190,000
# 1552   1,542,820,000
# 1553   1,597,780,000
# 1554   1,491,160,000
# 1555   1,500,520,000
#
# [1556 rows x 7 columns]

# %% [markdown]
# Podemos observar que para este dataset tenemos 1556 entradas de datos con 7 variables distintas. Pero esto no es suficiente para elegir el algoritmo a implememtar. Ahora veamos como se comportan las variables.

# %%
import matplotlib.pyplot as plt

# Graficar la evolución del precio de cierre
plt.figure(figsize=(12,5))
plt.plot(df['Date'], df['Close'], label='Precio de cierre (Close)')
plt.title('Evolución del precio del Bitcoin')
plt.xlabel('Fecha')
plt.ylabel('Precio (USD)')
plt.legend()
plt.show()

# %% [markdown]
# Veamos este gráfico de la tendecia del precio del bitcoin. Se puede apreciar que este no sigue una tendencia lineal. De hecho hay saltos bruscos, picos y subidas/bajadas caoticas.
